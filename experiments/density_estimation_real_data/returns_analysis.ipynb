# %%
import torch
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import seaborn as sns

# %%
from tailnflows.utils import load_raw_data, load_experiment_output_data

# raw_data = load_raw_data('2024-05-de-sp500-new')
# raw_data_2 = load_raw_data('2024-05-de-sp500-b8')
# raw_data_3 = load_raw_data('2024-05-de-sp500-ttf-init')
# raw_data_4 = load_raw_data('2024-05-de-sp500-ttf-init-d2')

# %%
old_ttf_dats = ttf_dats
old_ttf_dats
# Out:
# {'insurance-0-normal': [{'model': 'normal',
#    'dim': 2,
#    'seed': 2100,
#    'split': 0,
#    'tst_ll': 1.4551600217819214,
#    'val_ll': 1.6031156778335571,
#    'tst_ix': 170,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal',
#    'dim': 2,
#    'seed': 2200,
#    'split': 0,
#    'tst_ll': 1.3955061435699463,
#    'val_ll': 1.550775408744812,
#    'tst_ix': 1110,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal',
#    'dim': 2,
#    'seed': 2300,
#    'split': 0,
#    'tst_ll': 1.4187146425247192,
#    'val_ll': 1.5724153518676758,
#    'tst_ix': 710,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal',
#    'dim': 2,
#    'seed': 2400,
#    'split': 0,
#    'tst_ll': 1.386107325553894,
#    'val_ll': 1.5616538524627686,
#    'tst_ix': 1410,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal',
#    'dim': 2,
#    'seed': 2500,
#    'split': 0,
#    'tst_ll': 1.4372762441635132,
#    'val_ll': 1.5566813945770264,
#    'tst_ix': 560,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal',
#    'dim': 2,
#    'seed': 2600,
#    'split': 0,
#    'tst_ll': 1.4126561880111694,
#    'val_ll': 1.527862310409546,
#    'tst_ix': 700,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal',
#    'dim': 2,
#    'seed': 2700,
#    'split': 0,
#    'tst_ll': 1.3783446550369263,
#    'val_ll': 1.5592771768569946,
#    'tst_ix': 580,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal',
#    'dim': 2,
#    'seed': 2800,
#    'split': 0,
#    'tst_ll': 1.4631072282791138,
#    'val_ll': 1.5452040433883667,
#    'tst_ix': 820,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal',
#    'dim': 2,
#    'seed': 2900,
#    'split': 0,
#    'tst_ll': 1.364430546760559,
#    'val_ll': 1.5701615810394287,
#    'tst_ix': 680,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal',
#    'dim': 2,
#    'seed': 3000,
#    'split': 0,
#    'tst_ll': 1.381035327911377,
#    'val_ll': 1.5098979473114014,
#    'tst_ix': 810,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None}],
#  'insurance-0-ttf_fix': [{'model': 'ttf_fix',
#    'dim': 2,
#    'seed': 2100,
#    'split': 0,
#    'tst_ll': 1.3662065267562866,
#    'val_ll': 1.5745500326156616,
#    'tst_ix': 370,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf_fix',
#    'dim': 2,
#    'seed': 2200,
#    'split': 0,
#    'tst_ll': 1.4104543924331665,
#    'val_ll': 1.5669125318527222,
#    'tst_ix': 1670,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf_fix',
#    'dim': 2,
#    'seed': 2300,
#    'split': 0,
#    'tst_ll': 1.398097038269043,
#    'val_ll': 1.562491536140442,
#    'tst_ix': 880,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf_fix',
#    'dim': 2,
#    'seed': 2400,
#    'split': 0,
#    'tst_ll': 1.3749713897705078,
#    'val_ll': 1.528167724609375,
#    'tst_ix': 990,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf_fix',
#    'dim': 2,
#    'seed': 2500,
#    'split': 0,
#    'tst_ll': 1.362660527229309,
#    'val_ll': 1.5739645957946777,
#    'tst_ix': 670,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf_fix',
#    'dim': 2,
#    'seed': 2600,
#    'split': 0,
#    'tst_ll': 1.3877613544464111,
#    'val_ll': 1.5761395692825317,
#    'tst_ix': 1060,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf_fix',
#    'dim': 2,
#    'seed': 2700,
#    'split': 0,
#    'tst_ll': 1.3832063674926758,
#    'val_ll': 1.5483487844467163,
#    'tst_ix': 970,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf_fix',
#    'dim': 2,
#    'seed': 2800,
#    'split': 0,
#    'tst_ll': 1.3759149312973022,
#    'val_ll': 1.548079490661621,
#    'tst_ix': 860,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf_fix',
#    'dim': 2,
#    'seed': 2900,
#    'split': 0,
#    'tst_ll': 1.3746521472930908,
#    'val_ll': 1.5511046648025513,
#    'tst_ix': 2160,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf_fix',
#    'dim': 2,
#    'seed': 3000,
#    'split': 0,
#    'tst_ll': 1.375669240951538,
#    'val_ll': 1.5623760223388672,
#    'tst_ix': 310,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None}],
#  'insurance-0-normal_preprocess': [{'model': 'normal_preprocess',
#    'dim': 2,
#    'seed': 2100,
#    'split': 0,
#    'tst_ll': 1.3852143287658691,
#    'val_ll': 0.9826626181602478,
#    'tst_ix': 580,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal_preprocess',
#    'dim': 2,
#    'seed': 2200,
#    'split': 0,
#    'tst_ll': 1.3795298337936401,
#    'val_ll': 0.9727316498756409,
#    'tst_ix': 960,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal_preprocess',
#    'dim': 2,
#    'seed': 2300,
#    'split': 0,
#    'tst_ll': 1.3789361715316772,
#    'val_ll': 0.9887364506721497,
#    'tst_ix': 1420,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal_preprocess',
#    'dim': 2,
#    'seed': 2400,
#    'split': 0,
#    'tst_ll': 1.355147361755371,
#    'val_ll': 0.951401948928833,
#    'tst_ix': 700,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal_preprocess',
#    'dim': 2,
#    'seed': 2500,
#    'split': 0,
#    'tst_ll': 1.3914761543273926,
#    'val_ll': 0.9882622957229614,
#    'tst_ix': 420,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal_preprocess',
#    'dim': 2,
#    'seed': 2600,
#    'split': 0,
#    'tst_ll': 1.3608635663986206,
#    'val_ll': 0.9647689461708069,
#    'tst_ix': 940,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal_preprocess',
#    'dim': 2,
#    'seed': 2700,
#    'split': 0,
#    'tst_ll': 1.4030858278274536,
#    'val_ll': 1.0209994316101074,
#    'tst_ix': 300,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal_preprocess',
#    'dim': 2,
#    'seed': 2800,
#    'split': 0,
#    'tst_ll': 1.4142169952392578,
#    'val_ll': 0.9778100848197937,
#    'tst_ix': 640,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal_preprocess',
#    'dim': 2,
#    'seed': 2900,
#    'split': 0,
#    'tst_ll': 1.341156244277954,
#    'val_ll': 0.9450924396514893,
#    'tst_ix': 2540,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'normal_preprocess',
#    'dim': 2,
#    'seed': 3000,
#    'split': 0,
#    'tst_ll': 1.3981761932373047,
#    'val_ll': 0.9720427393913269,
#    'tst_ix': 520,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None}],
#  'insurance-0-comet': [{'model': 'comet',
#    'dim': 2,
#    'seed': 2100,
#    'split': 0,
#    'tst_ll': 1.3761907815933228,
#    'val_ll': 1.564643383026123,
#    'tst_ix': 100,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'comet',
#    'dim': 2,
#    'seed': 2200,
#    'split': 0,
#    'tst_ll': 1.452170729637146,
#    'val_ll': 1.5877954959869385,
#    'tst_ix': 760,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'comet',
#    'dim': 2,
#    'seed': 2300,
#    'split': 0,
#    'tst_ll': 1.3838253021240234,
#    'val_ll': 1.554930567741394,
#    'tst_ix': 230,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'comet',
#    'dim': 2,
#    'seed': 2400,
#    'split': 0,
#    'tst_ll': 1.4157201051712036,
#    'val_ll': 1.6203124523162842,
#    'tst_ix': 630,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'comet',
#    'dim': 2,
#    'seed': 2500,
#    'split': 0,
#    'tst_ll': 1.4050668478012085,
#    'val_ll': 1.5975474119186401,
#    'tst_ix': 160,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'comet',
#    'dim': 2,
#    'seed': 2600,
#    'split': 0,
#    'tst_ll': 1.431860327720642,
#    'val_ll': 1.5835810899734497,
#    'tst_ix': 770,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'comet',
#    'dim': 2,
#    'seed': 2700,
#    'split': 0,
#    'tst_ll': 1.4283161163330078,
#    'val_ll': 1.5763195753097534,
#    'tst_ix': 410,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'comet',
#    'dim': 2,
#    'seed': 2800,
#    'split': 0,
#    'tst_ll': 1.4369072914123535,
#    'val_ll': 1.5601518154144287,
#    'tst_ix': 960,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'comet',
#    'dim': 2,
#    'seed': 2900,
#    'split': 0,
#    'tst_ll': 1.360176682472229,
#    'val_ll': 1.5293039083480835,
#    'tst_ix': 890,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'comet',
#    'dim': 2,
#    'seed': 3000,
#    'split': 0,
#    'tst_ll': 1.426895022392273,
#    'val_ll': 1.5469858646392822,
#    'tst_ix': 370,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None}],
#  'insurance-0-ttf': [{'model': 'ttf',
#    'dim': 2,
#    'seed': 2100,
#    'split': 0,
#    'tst_ll': 1.3609973192214966,
#    'val_ll': 1.5379494428634644,
#    'tst_ix': 570,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf',
#    'dim': 2,
#    'seed': 2200,
#    'split': 0,
#    'tst_ll': 1.3882545232772827,
#    'val_ll': 1.562704086303711,
#    'tst_ix': 950,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf',
#    'dim': 2,
#    'seed': 2300,
#    'split': 0,
#    'tst_ll': 1.3572131395339966,
#    'val_ll': 1.5538853406906128,
#    'tst_ix': 1080,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf',
#    'dim': 2,
#    'seed': 2400,
#    'split': 0,
#    'tst_ll': 1.353602409362793,
#    'val_ll': 1.5931626558303833,
#    'tst_ix': 670,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf',
#    'dim': 2,
#    'seed': 2500,
#    'split': 0,
#    'tst_ll': 1.3723212480545044,
#    'val_ll': 1.532894253730774,
#    'tst_ix': 830,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf',
#    'dim': 2,
#    'seed': 2600,
#    'split': 0,
#    'tst_ll': 1.3726681470870972,
#    'val_ll': 1.5634088516235352,
#    'tst_ix': 480,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf',
#    'dim': 2,
#    'seed': 2700,
#    'split': 0,
#    'tst_ll': 1.3751027584075928,
#    'val_ll': 1.5635241270065308,
#    'tst_ix': 810,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf',
#    'dim': 2,
#    'seed': 2800,
#    'split': 0,
#    'tst_ll': 1.4017434120178223,
#    'val_ll': 1.5988638401031494,
#    'tst_ix': 400,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf',
#    'dim': 2,
#    'seed': 2900,
#    'split': 0,
#    'tst_ll': 1.3633795976638794,
#    'val_ll': 1.5912808179855347,
#    'tst_ix': 470,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'ttf',
#    'dim': 2,
#    'seed': 3000,
#    'split': 0,
#    'tst_ll': 1.3413017988204956,
#    'val_ll': 1.573714256286621,
#    'tst_ix': 1000,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None}],
#  'insurance-0-mtaf': [{'model': 'mtaf',
#    'dim': 2,
#    'seed': 2100,
#    'split': 0,
#    'tst_ll': 1.5958292484283447,
#    'val_ll': 1.7383208274841309,
#    'tst_ix': 540,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'mtaf',
#    'dim': 2,
#    'seed': 2200,
#    'split': 0,
#    'tst_ll': 1.5518519878387451,
#    'val_ll': 1.6906095743179321,
#    'tst_ix': 1140,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'mtaf',
#    'dim': 2,
#    'seed': 2300,
#    'split': 0,
#    'tst_ll': 1.4918899536132812,
#    'val_ll': 1.6309877634048462,
#    'tst_ix': 730,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'mtaf',
#    'dim': 2,
#    'seed': 2400,
#    'split': 0,
#    'tst_ll': 1.5212639570236206,
#    'val_ll': 1.689354419708252,
#    'tst_ix': 650,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'mtaf',
#    'dim': 2,
#    'seed': 2500,
#    'split': 0,
#    'tst_ll': 1.5270321369171143,
#    'val_ll': 1.6710158586502075,
#    'tst_ix': 830,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'mtaf',
#    'dim': 2,
#    'seed': 2600,
#    'split': 0,
#    'tst_ll': 1.4980822801589966,
#    'val_ll': 1.6702381372451782,
#    'tst_ix': 620,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'mtaf',
#    'dim': 2,
#    'seed': 2700,
#    'split': 0,
#    'tst_ll': 1.4933689832687378,
#    'val_ll': 1.6766679286956787,
#    'tst_ix': 520,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'mtaf',
#    'dim': 2,
#    'seed': 2800,
#    'split': 0,
#    'tst_ll': 1.4900132417678833,
#    'val_ll': 1.6683995723724365,
#    'tst_ix': 280,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'mtaf',
#    'dim': 2,
#    'seed': 2900,
#    'split': 0,
#    'tst_ll': 1.5485177040100098,
#    'val_ll': 1.7217363119125366,
#    'tst_ix': 350,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'mtaf',
#    'dim': 2,
#    'seed': 3000,
#    'split': 0,
#    'tst_ll': 1.5057803392410278,
#    'val_ll': 1.637816071510315,
#    'tst_ix': 470,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None}],
#  'insurance-0-gtaf': [{'model': 'gtaf',
#    'dim': 2,
#    'seed': 2100,
#    'split': 0,
#    'tst_ll': 1.4642924070358276,
#    'val_ll': 1.6165180206298828,
#    'tst_ix': 300,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'gtaf',
#    'dim': 2,
#    'seed': 2200,
#    'split': 0,
#    'tst_ll': 1.3982454538345337,
#    'val_ll': 1.5338311195373535,
#    'tst_ix': 360,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'gtaf',
#    'dim': 2,
#    'seed': 2300,
#    'split': 0,
#    'tst_ll': 1.3956772089004517,
#    'val_ll': 1.572251558303833,
#    'tst_ix': 1150,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'gtaf',
#    'dim': 2,
#    'seed': 2400,
#    'split': 0,
#    'tst_ll': 1.3780649900436401,
#    'val_ll': 1.5199980735778809,
#    'tst_ix': 890,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'gtaf',
#    'dim': 2,
#    'seed': 2500,
#    'split': 0,
#    'tst_ll': 1.414772868156433,
#    'val_ll': 1.5388827323913574,
#    'tst_ix': 1210,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'gtaf',
#    'dim': 2,
#    'seed': 2600,
#    'split': 0,
#    'tst_ll': 1.4220600128173828,
#    'val_ll': 1.6315711736679077,
#    'tst_ix': 630,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'gtaf',
#    'dim': 2,
#    'seed': 2700,
#    'split': 0,
#    'tst_ll': 1.394276738166809,
#    'val_ll': 1.5696121454238892,
#    'tst_ix': 590,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'gtaf',
#    'dim': 2,
#    'seed': 2800,
#    'split': 0,
#    'tst_ll': 1.423887014389038,
#    'val_ll': 1.606413722038269,
#    'tst_ix': 1860,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'gtaf',
#    'dim': 2,
#    'seed': 2900,
#    'split': 0,
#    'tst_ll': 1.3850419521331787,
#    'val_ll': 1.554936170578003,
#    'tst_ix': 760,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None},
#   {'model': 'gtaf',
#    'dim': 2,
#    'seed': 3000,
#    'split': 0,
#    'tst_ll': 1.4580988883972168,
#    'val_ll': 1.577939748764038,
#    'tst_ix': 1240,
#    'lr': 0.005,
#    'num_steps': 10000,
#    'batch_size': 512,
#    'early_stop_patience': 500,
#    'num_evals': 1000,
#    'lr_scheduler': None}]}

# %%
import numpy as np

# insurance: 2025-01-newrun
# sp500: 2025-01-newrun + 2025-01-tst (comet)
ttf_dats = load_experiment_output_data('sp500/2025-01-tst')

rows = []
for model, run_datas in ttf_dats.items():
    for rd in run_datas:
        if rd['model'] != 'normal_preprocess':
            
            rows.append({
                'data': model.split('-')[0],
                **rd
            })

# for model, run_datas in load_experiment_output_data('sp500/2025-01-tst').items():
#     for rd in run_datas:
#         rows.append({
#             'data': model.split('-')[0],
#             **rd
#         })

df = pd.DataFrame(rows)

# grouper = ['model', 'lr', 'batch_size',  'depth', 'num_bins', 'tail_bound']
# grouper = ['lr', 'batch_size',  'depth', 'num_bins', 'tail_bound']
grouper = ['model']

selector = np.ones(len(df), dtype=bool)
# selector &= df['batch_size'] == 100
# selector &= df['tail_bound'] == 2.5
# selector = np.logical_and(
#     df['batch_size'] == 100,
#     df['tail_bound'] == 2.5
# )
df = df[selector]

grouped = df.groupby(grouper)
agg = grouped[['val_ll', 'tst_ll']].agg(['mean', 'sem', 'std'])
# agg['p1'] = agg['mean'] + agg['sem']
best = agg['tst_ll'].sort_values(by='mean')
within = best.iloc[0]['mean'] + best.iloc[0]['std']

def highlight_by_mean(row, threshold=7):
    """
    Highlight the row if the 'Mean' value is above the given threshold.
    """
    if row['mean'] < threshold:
        # Highlight entire row in a light green
        return ['background-color: #dfffdf'] * len(row)
    else:
        # No highlight
        return ['background-color: white'] * len(row)
    
best.style.apply(
    highlight_by_mean, 
    axis=1, 
    threshold=within
)
# Out:
# <style type="text/css">
# #T_bcfcb_row0_col0, #T_bcfcb_row0_col1, #T_bcfcb_row0_col2 {
#   background-color: #dfffdf;
# }
# </style>
# <table id="T_bcfcb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcfcb_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_bcfcb_level0_col1" class="col_heading level0 col1" >sem</th>
#       <th id="T_bcfcb_level0_col2" class="col_heading level0 col2" >std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcfcb_level0_row0" class="row_heading level0 row0" >comet</th>
#       <td id="T_bcfcb_row0_col0" class="data row0 col0" >324.381769</td>
#       <td id="T_bcfcb_row0_col1" class="data row0 col1" >0.182739</td>
#       <td id="T_bcfcb_row0_col2" class="data row0 col2" >0.577872</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Out:
# 0.0005

# %%
from matplotlib.patches import Patch

color_palette = plt.get_cmap('tab10', len(agg.index))  # Using a colormap

model_to_color = {model: color_palette(i) for i, model in enumerate(agg.index)}

selected_ix = []
for ix, group in grouped:
    plt.scatter(group.val_ll, group.tst_ll, color=model_to_color[ix], marker='.')
    # plt.scatter(ix[-2], group.tst_ll, c=model_to_color[ix])
    selected_ix.append(ix)

plt.ylabel('tst')
plt.xlabel('val')
legend_elements = [Patch(facecolor=model_to_color[model], edgecolor='black', label=model) 
                   for model in selected_ix]
plt.legend(handles=legend_elements, title="Models", loc='upper left', bbox_to_anchor=(1.05, 1))
plt.grid()
plt.show()

# %%
ttf_runs = load_experiment_output_data('fama5/2025-01-optim')

# load_raw_data()
for label, runs in ttf_runs.items():
    for run in runs:
        losses = load_raw_data(run['loss_path'])[label][
            run['loss_ix']
        ]

        plt.title(f'{label} {run["lr"]} | {run["batch_size"]}')
        l, = plt.plot(losses['steps'], losses['losses'], label='')
        plt.plot(losses['steps'], losses['vlosses'], linestyle='--', c=l.get_color())
        plt.xlabel('update steps')
    # plt.ylim([0, 500])
    plt.grid()
    plt.show()

# %%
import pickle
tail_path = '/home/th17628/tailnflows/rough_work/climdex_tails.pkl'
with open(tail_path, 'rb') as f:
    marginal_dfs = pickle.load(f)

# %%
from pathlib import Path
from tailnflows.utils import get_data_path

data_source = "sp500"
tail_path = f'{get_data_path()}/splits/{data_source}/{split}'
if not Path(f"{tail_path}.p").is_file():
    raise Exception(
        f"Split data not present at {tail_path}.p, either configure "
        "TAILNFLOWS_DATA_DIR, or run `python experiments/density_estimation_real_data/generate_splits.py`"
    )
    
splits_and_tail = load_raw_data(tail_path)["experiment_data"][0]

# %%
rows = [
    {
        'model': label.split(' ')[0],
        **data
    }
    for label, experiments in raw_data.items()
    for data in experiments
]
# rows += [
#     {
#         'model': label.split(' ')[0]+ '_b8',
#         **data
#     }
#     for label, experiments in raw_data_2.items()
#     for data in experiments
# ]
# rows += [
#     {
#         'model': label.split(' ')[0]+ '_sinit',
#         **data
#     }
#     for label, experiments in raw_data_3.items()
#     for data in experiments
# ]
# rows += [
#     {
#         'model': label.split(' ')[0]+ '_d2',
#         **data
#     }
#     for label, experiments in raw_data_4.items()
#     for data in experiments
# ]

df = pd.DataFrame(rows)
df['test_neg_ll_per_dim'] = df['tst_neg_ll'] / df['dim']
df.head()
name_map = {
    'ttf_aff_u': 'TTF',
    'ttf_fix_aff_u': 'TTF (fix)',
    'mtaf': 'mTAF',
    'gtaf': 'gTAF',
}
df['readable_name'] = df['model'].apply(lambda x: name_map.get(x, x))

# %%
df.groupby('readable_name').count()
# Out:
#                model  dim  seed  tst_neg_ll  test_neg_ll_per_dim
# readable_name
# TTF               30   30    30          30                   30
# TTF (fix)         30   30    30          30                   30
# gTAF              30   30    30          30                   30
# mTAF              30   30    30          30                   30
# ttf               10   10    10          10                   10
# ttf_aff           10   10    10          10                   10
# ttf_fix           10   10    10          10                   10
# ttf_fix_aff       10   10    10          10                   10

# %%
target_dims = [100, 200, 300]
fig, axarr = plt.subplots(1, len(target_dims), figsize=(18, 6), tight_layout=True, sharey=True)
if len(target_dims) == 1:
  axarr = [axarr]

sns.set_style("whitegrid")
sns.set_context("paper", font_scale=2.)

for i, dim in enumerate(target_dims):
  j = 1

  wanted_data = df[df['dim'] == dim]

  sns.boxplot(
      data=wanted_data,
      x='test_neg_ll_per_dim',
      y='readable_name',
      order=['TTF (fix)', 'mTAF', 'TTF', 'gTAF'],
      orient='h',
      ax=axarr[i],
  )

  axarr[i].axhline(1.5, linestyle='--', c='black')
  axarr[i].set_title(f'dim={dim}')
  axarr[i].set_xlabel('')
  axarr[i].set_ylabel('Model')

  fig.add_subplot(111, frameon=False)
  plt.xlabel('Test Negative Log-Likelihood per Dimension')
  plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
  plt.tight_layout()
  plt.savefig(f"./real_sp500.png")

# %%
proc_data = []
for label, fit_data in raw_data.items():
  for (test_ll, dim) in fit_data:
    if label in models:
      plot_label = models[label]
      proc_data.append({'model': plot_label, 'test_neg_ll': test_ll, 'dim': dim})

df = pd.DataFrame(proc_data)

# %%
rd_path =  f'../../experiment_output/returns_2024-01-31.p'
rd_path2 =  f'../../experiment_output/returns_2024-02-08.p'

raw_data = pickle.load( open(rd_path, "rb" ) )
raw_data2 = pickle.load( open(rd_path2, "rb" ) )

raw_data['TTF_m_fix_new'] = raw_data2['TTF_m_fix']
raw_data['TTF_m_stable'] = raw_data2['TTF_m_stable']
raw_data['TTF_m_affine_stable'] = raw_data2['TTF_m_affine_stable_longer+']
raw_data['TTF_m_affine_fix'] = raw_data2['TTF_m_affine_fixed_longer+']
raw_data['TTF_m_affine_stable_new'] = raw_data2['TTF_m_affine_stable__new']
raw_data['TTF_m_affine_fix_new'] = raw_data2['TTF_m_affine_fixed_new']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 rd_path =  f'../../experiment_output/returns_2024-01-31.p'
#       2 rd_path2 =  f'../../experiment_output/returns_2024-02-08.p'
# ----> 4 raw_data = pickle.load( open(rd_path, "rb" ) )
#       5 raw_data2 = pickle.load( open(rd_path2, "rb" ) )
#
# File ~/miniconda3/envs/tailnflows/lib/python3.9/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../experiment_output/returns_2024-01-31.p'

# %%
models = {
    # 'gTAF': 'gTAF',
    # 'TTF_m_init_-0,5->1,5': 'TTF',
    'mTAF': 'mTAF',
    # 'TTF_m_fix': 'TTF (fix)',
    # 'TTF_m_fix_new': 'TTF (fix)',
    'TTF_m_stable': 'TTF',
    # 'TTF_m_affine_stable': 'TTF aff',
    # 'TTF_m_affine_stable_new': 'TTF + affine',
    # 'TTF_m_affine_fix': 'TTF aff (fix)',
    # 'TTF_m_affine_fix_new': 'TTF + afffine (fix)',
}

# %%
df.test_neg_ll = df.test_neg_ll.astype('float')
target_dims = list(df.dim.unique())
target_dims = [100]
fig, axarr = plt.subplots(1, len(target_dims), figsize=(12, 6), tight_layout=True)
if len(target_dims) == 1:
  axarr = [axarr]

sns.set_style("whitegrid")
sns.set_context("paper", font_scale=2.)

for i, dim in enumerate(target_dims):
  j = 1

  wanted_data = df[df['dim'] == dim]

  sns.boxplot(
      data=wanted_data,
      x='test_neg_ll',
      y='model',
      order=models.values(),
      orient='h',
      ax=axarr[i],
  )

  axarr[i].set_title(f'dim={dim}')
  plt.tight_layout()
  plt.savefig(f"../../../ftfnf_writeup/graphics/real_sp500_dim_100_new.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 proc_data = []
# ----> 2 for label, fit_data in raw_data.items():
#       3   for (test_ll, dim) in fit_data:
#       4     if label in models:
#
# NameError: name 'raw_data' is not defined
